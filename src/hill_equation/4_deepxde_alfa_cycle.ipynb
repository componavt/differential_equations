# %% [markdown]
# <a href="https://colab.research.google.com/github/componavt/differential_equations/blob/main/src/hill_equation/4_deepxde_alfa_cycle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Neural Approximation of Hill-Type ODE
#
# - ODE: $ \displaystyle \frac{dx}{dt} = \frac{x^{1/\alpha}}{b^{1/\alpha} + x^{1/\alpha}} $
# - Condition: $ x(0) \approx b $, where $ b > 0 $ and $ \alpha \rightarrow 0 $ (stiff regime)
# - Neural Solvers: PINNs with FNNs (32x4, 64x4)
# - Baselines: RK45, BDF, Radau (SciPy)
# - Focus: Accuracy around $ t \approx 0 $, where stiffness dominates

# %% [markdown]
# # 🧠 PINNs Meet Hill-Like ODEs
# **Can neural nets compete with trusted numerical solvers? Let's find out!**
#
# - **ODE form**:
#   $ \displaystyle \frac{dx}{dt} = \frac{x^{1/\alpha}}{b^{1/\alpha} + x^{1/\alpha}} $ — steep, stiff, and nonlinear!
# - **Setup**:
#   - Initial state: $ x(0) \approx b $
#   - We're in the $ \alpha \rightarrow 0 $ world (very sharp transitions).
# - **Neural Nets**:
#   - Feedforward networks (FNNs) trained via DeepXDE.
#   - Multiple architectures tested: 32x4, 64x4, etc.
# - **Numerical Solvers**:
#   - `RK45` for adaptive precision
#   - `BDF` for stiffness
#   - `Radau` for stability
# - **Goal**: See how well PINNs approximate fast-changing dynamics vs. classical ODE solvers.

# %%
# Parameters
b = 1.0
x0 = b * 0.99999  # Initial condition x(0) ≈ b
nonuniformity_power = 3.0  # Controls how dense the points are near t = 1 (higher = denser)


# !pip install deepxde
import deepxde as dde
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import pickle
from deepxde.callbacks import Callback

# Use float64 globally to improve precision
np.set_printoptions(precision=8, suppress=True)
tf.keras.backend.set_floatx('float64')

dtype = "float64"
tf.keras.utils.set_random_seed(0)
tf.config.experimental.enable_tensor_float_32_execution(False)

# Alpha range with potential small values (log-spaced)
#alpha = 0.01
#alpha_list = np.logspace(-2, -5, 10)  # от 0.01 до 0.00001 логарифмически
alpha_list = np.logspace(-3, -7, 10)  # от 0.001 до 0.0000001 логарифмически
#alpha_list = np.logspace(-4, -9, 20)  # от 0.0001 до 0.000000001 логарифмически - много NaN

# %%
## Solution of ODE with Hill-like RHS: model comparison and approximation

# Callback for compact training log
#class CompactPrint(Callback):
#    def __init__(self):
#        super().__init__()

#    def on_train_end(self):
#        train = float(self.model.train_state.loss_train[-1])
#        test = float(self.model.train_state.loss_test[-1])
#        print(f"Step {self.model.train_state.step}: train={train:.1e}, test={test:.1e}")

# Define Hill-type equation generator (for dynamic alpha)
def get_hill_equation(alpha):
  def hill_equation(x, y):
     y_safe = tf.clip_by_value(y, 1e-6, 1e6)
     dy_t = dde.grad.jacobian(y, x, i=0, j=0) # dy/dt
     x_alpha = tf.pow(y_safe, 1 / alpha)      # x^(1/alpha)
     b_alpha = tf.pow(b, 1 / alpha)           # b^(1/alpha)
     return dy_t - x_alpha / (b_alpha + x_alpha)
  return hill_equation


# Time domain and initial condition
geom = dde.geometry.TimeDomain(0, 1)
ic = dde.icbc.IC(geom, lambda x: x0, lambda _, on_initial: on_initial)

# Model configurations to compare
#configs = [
#    (500, [1] + [32] * 4 + [1], "FNN 32x4, domain=500"),
#    (1000, [1] + [32] * 4 + [1], "FNN 32x4, domain=1000"),
#    (500, [1] + [128] * 6 + [1], "FNN 128x6, domain=500"),
#    (1000, [1] + [128] * 6 + [1], "FNN 128x6, domain=1000"),
#    (500, [1] + [128] * 8 + [1], "FNN 128x8, domain=500"),
#    (1000, [1] + [128] * 8 + [1], "FNN 128x8, domain=1000")
#]

configs = [
#    (500, [1] + [32] * 4 + [1], "FNN 32x4, domain=500"),
#    (1000, [1] + [32] * 4 + [1], "FNN 32x4, domain=1000"),
    (500, [1] + [64] * 4 + [1], "FNN 64x4, domain=500"),
]

# Prepare test time points (dense near t=0)
# Non-uniform test points: dense near t=0
N = 500
t_uniform = np.linspace(0, 1, N)  # Uniform grid in [0, 1]
t_test = 1 - (1 - t_uniform) ** nonuniformity_power # Skew distribution toward t=1: more points near 1, fewer near 0
t_test = np.unique(t_test).reshape(-1, 1) # Ensure strictly increasing and 2D
t_eval = np.sort(t_test.flatten())

# Plot setup
plt.figure(figsize=(12, 7))
styles = ['-', '--', ':', '-.', (0, (5, 1)), (0, (3, 1, 1, 1))]
markers = ['o', 's', '^', 'v', 'D', '*', 'x', 'P', 'H', '>']
colors = ['b', 'g', 'r', 'c', 'm', 'k', 'tab:orange', 'tab:purple', 'tab:brown', 'tab:gray']


# Train and evaluate neural models
results = []
all_losses = []

for a_index, alpha in enumerate(alpha_list):
  print(f"\n=== Training for alpha = {alpha:.5e} ===")

  def rhs(t, x):                      # Define RHS for SciPy integration
    x_safe = np.clip(x[0], 1e-6, 1e6)
    x_alpha = x_safe ** (1 / alpha)
    b_alpha = b ** (1 / alpha)
    return [x_alpha / (b_alpha + x_alpha)]

  for i, (num_domain, architecture, label) in enumerate(configs):
    print(f"\nTraining model: {label}")
    data = dde.data.PDE(
        geom,
        get_hill_equation(alpha),
        ic,
        num_domain=num_domain,
        num_boundary=2,
        num_test=500
    )
    net = dde.nn.FNN(architecture, "tanh", "Glorot normal")
    net.apply_output_transform(lambda x, y: y * 0.01 + b)
    model = dde.Model(data, net)
    model.compile("adam", lr=0.0001)
    loss_history, train_state = model.train(
        iterations=5000,
        display_every=1000,
        disregard_previous_best=True,
#        callbacks=[CompactPrint()]
    )
    try:
        model.compile("L-BFGS")
        model.train(iterations=500)
    except Exception as e:
        print(f"L-BFGS failed for {label}: {str(e)}")

    x_pred = model.predict(t_test)
    results.append((t_test, x_pred, f"{label}, α={alpha:.1e}"))
    all_losses.append((f"{label}, α={alpha:.1e}", loss_history))
    print(f"{label}: α={alpha:.1e} x∈[{np.nanmin(x_pred):.4f},{np.nanmax(x_pred):.4f}] loss={loss_history.loss_train[-1][0]:.2e}")

    #plt.plot(t_test, x_pred,
    #        linestyle=styles[i % len(styles)], color=colors[i % len(colors)],
    #        label=f"{label}, α={alpha:.1e}",
    #        linewidth=2)
    plt.plot(t_test, x_pred,
            linestyle=styles[a_index % len(styles)],
            color=colors[a_index % len(colors)],
            marker=markers[a_index % len(markers)],
            markevery=30, markersize=4,
            label=f"{label}, α={alpha:.1e}",
            linewidth=1.0)


# Add numerical solutions
#plt.plot(sol_rk45.t, sol_rk45.y[0], 'k--', label='RK45 (SciPy)', linewidth=2)
#plt.plot(sol_bdf.t, sol_bdf.y[0], 'm:', label='BDF (SciPy)', linewidth=2)
#plt.plot(sol_radau.t, sol_radau.y[0], 'c-.', label='Radau (SciPy)', linewidth=2)

# Save results for visualization-only reruns
with open("nn_results.pkl", "wb") as f:
    pickle.dump(results, f)

# Axis and title
plt.xlabel("Time (t)")
plt.ylabel("x(t)")
plt.title("Comparison of Neural Network Models and Solvers for Hill-Type ODE")
plt.legend()
plt.legend(fontsize=9)
plt.grid(True)
plt.tight_layout()
#plt.ylim(0.95, 0.975)
#plt.xlim(0, 0.02)
plt.show()
# Out:
# === Training for alpha = 1.00000e-03 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.090179 s
#
# 'compile' took 2.591713 s
#
# Training model...
#
# 0         [5.50e-02, 1.00e-10]    [5.43e-02, 1.00e-10]    []
# 5000      [6.46e-06, 3.41e-05]    [6.43e-06, 3.41e-05]    []
# Step 5000: train=3.4e-05, test=3.4e-05
#
# Best model at step 5000:
#   train loss: 4.06e-05
#   test loss: 4.05e-05
#   test metric: []
#
# 'train' took 42.467962 s
#
# Compiling model...
# 'compile' took 2.636034 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [6.46e-06, 3.41e-05]    [6.43e-06, 3.41e-05]    []
# 5017      [6.46e-06, 3.41e-05]    [6.43e-06, 3.41e-05]    []
#
# Best model at step 5000:
#   train loss: 4.06e-05
#   test loss: 4.05e-05
#   test metric: []
#
# 'train' took 26.979301 s
#
# FNN 64x4, domain=500: α=1.0e-03 x∈[0.9939,0.9942] loss=6.46e-06
#
# === Training for alpha = 3.59381e-04 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.144592 s
#
# 'compile' took 3.082258 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [1.99e-02, 1.00e-10]    [1.92e-02, 1.00e-10]    []
# 5000      [9.98e-07, 5.85e-06]    [9.92e-07, 5.85e-06]    []
# Step 5000: train=5.8e-06, test=5.8e-06
#
# Best model at step 5000:
#   train loss: 6.84e-06
#   test loss: 6.84e-06
#   test metric: []
#
# 'train' took 47.541711 s
#
# Compiling model...
# 'compile' took 3.586166 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [9.98e-07, 5.85e-06]    [9.92e-07, 5.85e-06]    []
# 5018      [9.98e-07, 5.85e-06]    [9.92e-07, 5.85e-06]    []
#
# Best model at step 5000:
#   train loss: 6.84e-06
#   test loss: 6.84e-06
#   test metric: []
#
# 'train' took 29.255466 s
#
# FNN 64x4, domain=500: α=3.6e-04 x∈[0.9974,0.9976] loss=9.98e-07
#
# === Training for alpha = 1.29155e-04 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.087952 s
#
# 'compile' took 2.147908 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [7.36e-03, 1.00e-10]    [6.73e-03, 1.00e-10]    []
# 5000      [1.48e-07, 9.58e-07]    [1.47e-07, 9.58e-07]    []
# Step 5000: train=9.6e-07, test=9.6e-07
#
# Best model at step 5000:
#   train loss: 1.11e-06
#   test loss: 1.11e-06
#   test metric: []
#
# 'train' took 42.930064 s
#
# Compiling model...
# 'compile' took 2.784418 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [1.48e-07, 9.58e-07]    [1.47e-07, 9.58e-07]    []
# 5021      [1.48e-07, 9.58e-07]    [1.47e-07, 9.58e-07]    []
#
# Best model at step 5000:
#   train loss: 1.11e-06
#   test loss: 1.11e-06
#   test metric: []
#
# 'train' took 29.264271 s
#
# FNN 64x4, domain=500: α=1.3e-04 x∈[0.9989,0.9990] loss=1.48e-07
#
# === Training for alpha = 4.64159e-05 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.132652 s
#
# 'compile' took 3.007435 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [2.82e-03, 1.00e-10]    [2.27e-03, 1.00e-10]    []
# 5000      [2.19e-08, 1.50e-07]    [2.16e-08, 1.50e-07]    []
# Step 5000: train=1.5e-07, test=1.5e-07
#
# Best model at step 5000:
#   train loss: 1.72e-07
#   test loss: 1.71e-07
#   test metric: []
#
# 'train' took 42.859072 s
#
# Compiling model...
# 'compile' took 2.746010 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [2.19e-08, 1.50e-07]    [2.16e-08, 1.50e-07]    []
# 5018      [2.19e-08, 1.50e-07]    [2.16e-08, 1.50e-07]    []
#
# Best model at step 5000:
#   train loss: 1.72e-07
#   test loss: 1.71e-07
#   test metric: []
#
# 'train' took 31.040818 s
#
# FNN 64x4, domain=500: α=4.6e-05 x∈[0.9996,0.9996] loss=2.19e-08
#
# === Training for alpha = 1.66810e-05 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.083956 s
#
# 'compile' took 7.376892 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [1.20e-03, 1.00e-10]    [6.76e-04, 1.00e-10]    []
# 5000      [3.07e-09, 2.22e-08]    [3.03e-09, 2.22e-08]    []
# Step 5000: train=2.2e-08, test=2.2e-08
#
# Best model at step 5000:
#   train loss: 2.53e-08
#   test loss: 2.52e-08
#   test metric: []
#
# 'train' took 63.727490 s
#
# Compiling model...
# 'compile' took 3.180239 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [3.07e-09, 2.22e-08]    [3.03e-09, 2.22e-08]    []
# 5018      [3.07e-09, 2.22e-08]    [3.03e-09, 2.22e-08]    []
#
# Best model at step 5000:
#   train loss: 2.53e-08
#   test loss: 2.52e-08
#   test metric: []
#
# 'train' took 35.604286 s
#
# FNN 64x4, domain=500: α=1.7e-05 x∈[0.9998,0.9998] loss=3.07e-09
#
# === Training for alpha = 5.99484e-06 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.092633 s
#
# 'compile' took 2.425198 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [6.44e-04, 1.00e-10]    [1.34e-04, 1.00e-10]    []
# 5000      [4.03e-10, 2.83e-09]    [3.98e-10, 2.83e-09]    []
# Step 5000: train=2.8e-09, test=2.8e-09
#
# Best model at step 5000:
#   train loss: 3.24e-09
#   test loss: 3.23e-09
#   test metric: []
#
# 'train' took 59.151566 s
#
# Compiling model...
# 'compile' took 3.116358 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [4.03e-10, 2.83e-09]    [3.98e-10, 2.83e-09]    []
# 5018      [4.03e-10, 2.83e-09]    [3.98e-10, 2.83e-09]    []
#
# Best model at step 5000:
#   train loss: 3.24e-09
#   test loss: 3.23e-09
#   test metric: []
#
# 'train' took 35.971665 s
#
# FNN 64x4, domain=500: α=6.0e-06 x∈[0.9999,0.9999] loss=4.03e-10
#
# === Training for alpha = 2.15443e-06 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.090149 s
#
# 'compile' took 2.586431 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [5.20e-04, 1.00e-10]    [1.42e-05, 1.00e-10]    []
# 5000      [1.14e-06, 2.70e-07]    [1.14e-06, 2.70e-07]    []
# Step 5000: train=2.7e-07, test=2.7e-07
#
# Best model at step 5000:
#   train loss: 1.41e-06
#   test loss: 1.41e-06
#   test metric: []
#
# 'train' took 46.204841 s
#
# Compiling model...
# 'compile' took 3.024749 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [1.14e-06, 2.70e-07]    [1.14e-06, 2.70e-07]    []
# 5018      [1.14e-06, 2.70e-07]    [1.14e-06, 2.70e-07]    []
#
# Best model at step 5000:
#   train loss: 1.41e-06
#   test loss: 1.41e-06
#   test metric: []
#
# 'train' took 36.009401 s
#
# FNN 64x4, domain=500: α=2.2e-06 x∈[0.9984,0.9995] loss=1.14e-06
#
# === Training for alpha = 7.74264e-07 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.090927 s
#
# 'compile' took 2.722255 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [5.17e-04, 1.00e-10]    [1.16e-05, 1.00e-10]    []
# 5000      [1.11e-09, 9.51e-08]    [1.12e-09, 9.51e-08]    []
# Step 5000: train=9.5e-08, test=9.5e-08
#
# Best model at step 5000:
#   train loss: 9.62e-08
#   test loss: 9.62e-08
#   test metric: []
#
# 'train' took 46.240731 s
#
# Compiling model...
# 'compile' took 3.125095 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [1.11e-09, 9.51e-08]    [1.12e-09, 9.51e-08]    []
# 5017      [1.11e-09, 9.51e-08]    [1.12e-09, 9.51e-08]    []
#
# Best model at step 5000:
#   train loss: 9.62e-08
#   test loss: 9.62e-08
#   test metric: []
#
# 'train' took 36.108399 s
#
# FNN 64x4, domain=500: α=7.7e-07 x∈[0.9997,0.9997] loss=1.11e-09
#
# === Training for alpha = 2.78256e-07 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.303356 s
#
# 'compile' took 2.803406 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [5.17e-04, 1.00e-10]    [1.16e-05, 1.00e-10]    []
# 5000      [8.24e-12, 1.13e-08]    [8.19e-12, 1.13e-08]    []
# Step 5000: train=1.1e-08, test=1.1e-08
#
# Best model at step 5000:
#   train loss: 1.13e-08
#   test loss: 1.13e-08
#   test metric: []
#
# 'train' took 45.406261 s
#
# Compiling model...
# 'compile' took 3.910092 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [8.24e-12, 1.13e-08]    [8.19e-12, 1.13e-08]    []
# 5017      [8.24e-12, 1.13e-08]    [8.19e-12, 1.13e-08]    []
#
# Best model at step 5000:
#   train loss: 1.13e-08
#   test loss: 1.13e-08
#   test metric: []
#
# 'train' took 36.749053 s
#
# FNN 64x4, domain=500: α=2.8e-07 x∈[0.9999,0.9999] loss=8.24e-12
#
# === Training for alpha = 1.00000e-07 ===
#
# Training model: FNN 64x4, domain=500
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.089073 s
#
# 'compile' took 2.502000 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [5.17e-04, 1.00e-10]    [1.16e-05, 1.00e-10]    []
# 5000      [nan, nan]              [nan, nan]              []
# Step 5000: train=nan, test=nan
#
# Best model at step 0:
#   train loss: 5.17e-04
#   test loss: 1.16e-05
#   test metric: []
#
# 'train' took 46.408403 s
#
# Compiling model...
# 'compile' took 3.213361 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [nan, nan]              [nan, nan]              []
# 5104      [nan, nan]              [nan, nan]              []
#
# Best model at step 0:
#   train loss: 5.17e-04
#   test loss: 1.16e-05
#   test metric: []
#
# 'train' took 41.534746 s
# /tmp/ipython-input-22-1461094263.py:101: RuntimeWarning: All-NaN slice encountered
#   print(f"{label}: α={alpha:.1e} x∈[{np.nanmin(x_pred):.4f},{np.nanmax(x_pred):.4f}] loss={loss_history.loss_train[-1][0]:.2e}")
# FNN 64x4, domain=500: α=1.0e-07 x∈[nan,nan] loss=nan

# %%
# Visualization block (can be run separately, new version)
import matplotlib.pyplot as plt
import pickle

# Load previously saved results
with open("nn_results.pkl", "rb") as f:
    results = pickle.load(f)


# Todo to include
#plt.plot(sol_rk45.t, sol_rk45.y[0], 'k--', label='RK45 (SciPy)', linewidth=2)
#plt.plot(sol_bdf.t, sol_bdf.y[0], 'm:', label='BDF (SciPy)', linewidth=2)
#plt.plot(sol_radau.t, sol_radau.y[0], 'c-.', label='Radau (SciPy)', linewidth=2)


plt.figure(figsize=(12, 7))
for a_index, (t_test, x_pred, label) in enumerate(results):
    plt.plot(t_test, x_pred,
             linestyle=styles[a_index % len(styles)],
             color=colors[a_index % len(colors)],
             marker=markers[a_index % len(markers)],
             markevery=30, markersize=4,
             label=label,
             linewidth=1.0)

plt.xlabel("Time (t)")
plt.ylabel("x(t)")
plt.title("Visualization from Saved Results")
plt.legend(fontsize=9)
plt.grid(True)
plt.tight_layout()
plt.show()
